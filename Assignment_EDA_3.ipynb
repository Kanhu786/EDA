# %% [markdown]
# # Categorical Data to Numerical Data

# %% [markdown]
# ## map

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"Visadataset - Visadataset.csv")

# %%
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d={"Denied":0,"Certified":1}
visa_df['case_status'].map(d)
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 25475    1
# 25476    1
# 25477    1
# 25478    1
# 25479    1
# Name: case_status, Length: 25480, dtype: int64

# %%
visa_df=pd.read_csv(r"Visadataset - Visadataset.csv")
d={"Denied":0,"Certified":1}
visa_df['case_status']=visa_df['case_status'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
d1={'Asia':1,'Africa':0,'North America':3,'Europe':2,'South America':5,'Oceania':4}
visa_df['continent']=visa_df['continent'].map(d1)
visa_df
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          1           High School                  N
# 1         EZYV02          1              Master's                  Y
# 2         EZYV03          1            Bachelor's                  N
# 3         EZYV04          1            Bachelor's                  N
# 4         EZYV05          0              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          1            Bachelor's                  Y
# 25476  EZYV25477          1           High School                  Y
# 25477  EZYV25478          1              Master's                  Y
# 25478  EZYV25479          1              Master's                  Y
# 25479  EZYV25480          1            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['education_of_employee'].unique()
# Out:
# array(['High School', "Master's", "Bachelor's", 'Doctorate'], dtype=object)

# %%
d2={"Bachelor's":0,'Doctorate':1,'High School':2,"Master's":3}
visa_df['education_of_employee']=visa_df['education_of_employee'].map(d2)
visa_df
# Out:
#          case_id  continent  education_of_employee has_job_experience  \
# 0         EZYV01          1                      2                  N
# 1         EZYV02          1                      3                  Y
# 2         EZYV03          1                      0                  N
# 3         EZYV04          1                      0                  N
# 4         EZYV05          0                      3                  Y
# ...          ...        ...                    ...                ...
# 25475  EZYV25476          1                      0                  Y
# 25476  EZYV25477          1                      2                  Y
# 25477  EZYV25478          1                      3                  Y
# 25478  EZYV25479          1                      3                  Y
# 25479  EZYV25480          1                      0                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['full_time_position'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
d3={'N':0,'Y':1}
visa_df['full_time_position']=visa_df['full_time_position'].map(d3)
visa_df
# Out:
#          case_id  continent  education_of_employee has_job_experience  \
# 0         EZYV01          1                      2                  N
# 1         EZYV02          1                      3                  Y
# 2         EZYV03          1                      0                  N
# 3         EZYV04          1                      0                  N
# 4         EZYV05          0                      3                  Y
# ...          ...        ...                    ...                ...
# 25475  EZYV25476          1                      0                  Y
# 25476  EZYV25477          1                      2                  Y
# 25477  EZYV25478          1                      3                  Y
# 25478  EZYV25479          1                      3                  Y
# 25479  EZYV25480          1                      0                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['has_job_experience'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
visa_df['has_job_experience']=visa_df['has_job_experience'].map(d3)
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa_df['requires_job_training'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
visa_df['requires_job_training']=visa_df['requires_job_training'].map(d3)
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa_df['region_of_employment'].unique()
# Out:
# array(['West', 'Northeast', 'South', 'Midwest', 'Island'], dtype=object)

# %%
d4={'Island':0,'Midwest':1,'Northeast':2,'South':3,'West':4}
visa_df['region_of_employment']=visa_df['region_of_employment'].map(d4)
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa_df['unit_of_wage'].unique()
# Out:
# array(['Hour', 'Year', 'Week', 'Month'], dtype=object)

# %%
d5={'Hour':0,'Month':1,'Week':2,'Year':3}
visa_df['unit_of_wage']=visa_df['unit_of_wage'].map(d5)
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa_df=pd.read_csv(r"Visadataset - Visadataset.csv")
cols=visa_df.select_dtypes(include='object').columns
for i in cols:
    lebals=list(visa_df[i].unique())
    values=[i for i in range(len(lebals))]
    d=dict(zip(lebals,values))
    visa_df[i]=visa_df[i].map(d)
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          0                      0                   0
# 1            1          0                      1                   1
# 2            2          0                      2                   0
# 3            3          0                      2                   0
# 4            4          1                      1                   1
# ...        ...        ...                    ...                 ...
# 25475    25475          0                      2                   1
# 25476    25476          0                      0                   1
# 25477    25477          0                      1                   1
# 25478    25478          0                      1                   1
# 25479    25479          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# ### Lebal Encoded

# %%
visa_df=pd.read_csv(r"Visadataset - Visadataset.csv")

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['continent']=le.fit_transform(visa_df['continent'])
visa_df
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          1           High School                  N
# 1         EZYV02          1              Master's                  Y
# 2         EZYV03          1            Bachelor's                  N
# 3         EZYV04          1            Bachelor's                  N
# 4         EZYV05          0              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          1            Bachelor's                  Y
# 25476  EZYV25477          1           High School                  Y
# 25477  EZYV25478          1              Master's                  Y
# 25478  EZYV25479          1              Master's                  Y
# 25479  EZYV25480          1            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['education_of_employee']=le.fit_transform(visa_df['education_of_employee'])
visa_df
# Out:
#          case_id  continent  education_of_employee has_job_experience  \
# 0         EZYV01          1                      2                  N
# 1         EZYV02          1                      3                  Y
# 2         EZYV03          1                      0                  N
# 3         EZYV04          1                      0                  N
# 4         EZYV05          0                      3                  Y
# ...          ...        ...                    ...                ...
# 25475  EZYV25476          1                      0                  Y
# 25476  EZYV25477          1                      2                  Y
# 25477  EZYV25478          1                      3                  Y
# 25478  EZYV25479          1                      3                  Y
# 25479  EZYV25480          1                      0                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['has_job_experience']=le.fit_transform(visa_df['has_job_experience'])
visa_df['requires_job_training']=le.fit_transform(visa_df['requires_job_training'])
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa_df['region_of_employment']=le.fit_transform(visa_df['region_of_employment'])
visa_df['unit_of_wage']=le.fit_transform(visa_df['unit_of_wage'])
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa_df['full_time_position']=le.fit_transform(visa_df['full_time_position'])
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa_df=pd.read_csv(r"Visadataset - Visadataset.csv")
cols=visa_df.select_dtypes(include='object').columns
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cols:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %%
visa_df=pd.read_csv(r"Visadataset - Visadataset.csv")
print(visa_df['education_of_employee'].values)
print(le.fit_transform(visa_df['education_of_employee']))
# Out:
# ['High School' "Master's" "Bachelor's" ... "Master's" "Master's"
#  "Bachelor's"]
# [2 3 0 ... 3 3 0]

# %% [markdown]
# # np.where

# %%
visa_df=pd.read_csv(r"Visadataset - Visadataset.csv")
con=visa_df['case_status']=='Certified'
visa_df['case_status']=np.where(con,0,1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
con1=visa_df['has_job_experience']=='Y'
visa_df['has_job_experience']=np.where(con1,0,1)
visa_df
# Out:
#          case_id continent education_of_employee  has_job_experience  \
# 0         EZYV01      Asia           High School                   1
# 1         EZYV02      Asia              Master's                   0
# 2         EZYV03      Asia            Bachelor's                   1
# 3         EZYV04      Asia            Bachelor's                   1
# 4         EZYV05    Africa              Master's                   0
# ...          ...       ...                   ...                 ...
# 25475  EZYV25476      Asia            Bachelor's                   0
# 25476  EZYV25477      Asia           High School                   0
# 25477  EZYV25478      Asia              Master's                   0
# 25478  EZYV25479      Asia              Master's                   0
# 25479  EZYV25480      Asia            Bachelor's                   0
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
con1=visa_df['requires_job_training']=='Y'
visa_df['requires_job_training']=np.where(con1,0,1)
visa_df
# Out:
#          case_id continent education_of_employee  has_job_experience  \
# 0         EZYV01      Asia           High School                   1
# 1         EZYV02      Asia              Master's                   0
# 2         EZYV03      Asia            Bachelor's                   1
# 3         EZYV04      Asia            Bachelor's                   1
# 4         EZYV05    Africa              Master's                   0
# ...          ...       ...                   ...                 ...
# 25475  EZYV25476      Asia            Bachelor's                   0
# 25476  EZYV25477      Asia           High School                   0
# 25477  EZYV25478      Asia              Master's                   0
# 25478  EZYV25479      Asia              Master's                   0
# 25479  EZYV25480      Asia            Bachelor's                   0
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          1            14513         2007
# ...
