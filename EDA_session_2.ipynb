# %% [markdown]
# ## How to read a data frame

# %% [markdown]
# - location , file name, extention
#
# - I went to read data1
#
# - location is not requrid because

# %%
import pandas as pd

# %%
pd.read_csv("data.csv")
# Out:
#   Unnamed: 0     Name  Age  slary
# 0          A    Ayush   20  10000
# 1          B  Avinash   25  20000
# 2          C    Akash   30  39000

# %%
pd.read_excel('data2.xlsx')
# Out:
#   Unnamed: 0     Name  Age  slary
# 0          A    Ayush   20  10000
# 1          B  Avinash   25  20000
# 2          C    Akash   30  39000

# %%
visa_df=pd.read_csv(r"C:\Users\kanhu\OneDrive\Documents\data files\Visadataset - Visadataset.csv")

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
bank_df=pd.read_csv(r"C:\Users\kanhu\OneDrive\Documents\data files\bank - bank.csv")
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# ## create data

# %%
name=['Avinash','Prabhas','NTR']
age=[25,30,35]
pd.DataFrame(zip(name,age),columns=['Names','Age'])
# Out:
#      Names  Age
# 0  Avinash   25
# 1  Prabhas   30
# 2      NTR   35

# %%
dic={'Names':['Avinash','Prabhas','NTR'],
     'Ages':[25,30,35]}
dic
# Out:
# {'Names': ['Avinash', 'Prabhas', 'NTR'], 'Ages': [25, 30, 35]}

# %%
pd.DataFrame(dic)
#keys becomes columns
# Out:
#      Names  Ages
# 0  Avinash    25
# 1  Prabhas    30
# 2      NTR    35

# %%
dic1={'Names':'Avinash',
     'Ages':25,
    'City':'Hyd'}
pd.DataFrame(dic1,index=[1,2,3])
# Out:
#      Names  Ages City
# 1  Avinash    25  Hyd
# 2  Avinash    25  Hyd
# 3  Avinash    25  Hyd
